# %% [markdown]
# # Homework 7, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx", nrows = 30000, na_values= 'Unknown')

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.
#
# * *Tip: there's an option with `.read_csv` to only read in a certain number of rows*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Owner Zip Code          30000 non-null  int64
#  1   Animal Name             29743 non-null  object
#  2   Animal Gender           30000 non-null  object
#  3   Primary Breed           25223 non-null  object
#  4   Secondary Breed         3983 non-null   object
#  5   Animal Dominant Color   29885 non-null  object
#  6   Animal Secondary Color  20946 non-null  object
#  7   Animal Third Color      6629 non-null   object
#  8   Animal Birth            30000 non-null  datetime64[ns]
#  9   Spayed or Neut          30000 non-null  object
#  10  Guard or Trained        19826 non-null  object
#  11  Vaccinated              30000 non-null  object
#  12  Application Date        30000 non-null  datetime64[ns]
#  13  License Issued Date     30000 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# The dataset contains a list of pet dogs. The data also includes owner zip code aka where the dog lives, and also whether the dog is vaccinated or not.

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [raw]
# Are most guard dogs female or male?
# what percentage of dogs are vaccinated
# What are the most common breeds
# What breeds aren't vaccinated?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df.columns = df.columns.str.lower().str.replace(" ","_")
df.primary_breed.value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown
#
# * *Tip: Maybe you want to go back to your `.read_csv` and use `na_values=`? Maybe not? Up to you!*

# %%
df.primary_breed.value_counts().head(10).sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What are the most popular dog names?

# %%
df.animal_name.value_counts()
# Out:
# UNKNOWN          203
# Max              202
# Bella            193
# Charlie          172
# Lola             146
#                 ...
# Bluno              1
# DARBY              1
# CHARLEY VIVAR      1
# TINY               1
# Squeeze            1
# Name: animal_name, Length: 13720, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df.animal_name=="Max"]
(df.animal_name=="Maxwell").value_counts()

#df.animal_name=="Maxwell".value_counts() doesnt work bc it's just trying to count maxwell
# Out:
# False    29989
# True        11
# Name: animal_name, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?

# %%
df.guard_or_trained.value_counts(normalize=True)
# Out:
# No     0.999143
# Yes    0.000857
# Name: guard_or_trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df.guard_or_trained.value_counts(dropna=False)
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: guard_or_trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`. Think about missing data!

# %%
df.head()
# Out:
#    owner_zip_code   animal_name animal_gender         primary_breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   secondary_breed animal_dominant_color animal_secondary_color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   animal_third_color animal_birth spayed_or_neut guard_or_trained vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## Maybe fill in all of those empty "Guard or Trained" columns with "No"? Or as `NaN`?
#
# Can we make an assumption either way? Then check your result with another `.value_counts()`

# %%
#df.guard_or_trained.replace({"NaN": "No"})

df.guard_or_trained.fillna("No").value_counts()
# Out:
# No     29983
# Yes       17
# Name: guard_or_trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
#Can I just count the values that are yes?################################################
#df.groupby(by="guard_or_trained").primary_breed.value_counts("primary_breed"=="Yes")

df[df.guard_or_trained=="Yes"].primary_breed.value_counts()
# Out:
# German Shepherd Dog           3
# Poodle, Standard              1
# German Shepherd Crossbreed    1
# Labrador Retriever            1
# Doberman Pinscher             1
# Shih Tzu                      1
# Rottweiler                    1
# Golden Retriever              1
# Schnauzer, Miniature          1
# Yorkshire Terrier             1
# Name: primary_breed, dtype: int64

# %%
pd.crosstab(df.guard_or_trained, df.primary_breed)
# Out:
# primary_breed     Afghan Hound  Akita  Akita Crossbreed  American Bully  \
# guard_or_trained
# No                           4     28                 6               1
# Yes                          0      0                 0               0
#
# primary_breed     American Eskimo dog  American Pit Bull Mix / Pit Bull Mix  \
# guard_or_trained
# No                                 46                                   305
# Yes                                 0                                     0
#
# primary_breed     American Pit Bull Terrier/Pit Bull  \
# guard_or_trained
# No                                               348
# Yes                                                0
#
# primary_breed     American Staffordshire Terrier   Australian Cattle Dog  \
# guard_or_trained
# No                                             89                      1
# Yes                                             0                      0
#
# ...

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df['animal_birth_year'] = df['animal_birth'].apply(lambda birth: birth.year)
df
# Out:
#        owner_zip_code   animal_name animal_gender         primary_breed  \
# 0               10024     BLUE MACK             M                   NaN
# 1               10461  Indie Zephir             M            Rottweiler
# 2               10013         Bilal             M  Australian Cattledog
# 3               10025         Buddy             M                   NaN
# 4               10013           Ali             M               Basenji
# ...               ...           ...           ...                   ...
# 29995           11372         Bella             F                   NaN
# 29996           11417         Sadie             F  Schnauzer, Miniature
# 29997           11228       unknown             M            Pomeranian
# 29998           11217         daisy             F                   NaN
# 29999           10038       Squeeze             M              Shih Tzu
#
#       secondary_breed animal_dominant_color animal_secondary_color  \
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df['age'] = 2022 - df['animal_birth_year']

# %% [markdown]
# # Joining data together

# %%
df.age.mean()
# Out:
# 12.712433333333333

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
df_nyc = pd.read_csv("zipcodes-neighborhoods.csv")
df_nyc
# Out:
#                  neighborhood    zip        borough
# 0               Central Bronx  10453          Bronx
# 1               Central Bronx  10457          Bronx
# 2               Central Bronx  10460          Bronx
# 3      Bronx Park and Fordham  10458          Bronx
# 4      Bronx Park and Fordham  10467          Bronx
# ..                        ...    ...            ...
# 173               South Shore  10312  Staten Island
# 174  Stapleton and St. George  10301  Staten Island
# 175  Stapleton and St. George  10304  Staten Island
# 176  Stapleton and St. George  10305  Staten Island
# 177                Mid-Island  10314  Staten Island
#
# [178 rows x 3 columns]

# %%
merged_df = df.merge(df_nyc, left_on='owner_zip_code', right_on='zip')

# %%
merged_df.head(25)
# Out:
#     owner_zip_code   animal_name animal_gender  \
# 0            10024     BLUE MACK             M
# 1            10024         Louie             M
# 2            10024         Tosha             F
# 3            10024       Poppett             F
# 4            10024        Harlen             M
# 5            10024        Barney             M
# 6            10024        Peyton             M
# 7            10024        Phoebe             F
# 8            10024          Baci             F
# 9            10024  Delilah Eddy             F
# 10           10024         Louis             M
# 11           10024       Addison             F
# 12           10024      Scarlett             F
# 13           10024          Joey             M
# 14           10024        Cooper             M
# 15           10024          Cleo             F
# 16           10024        Wynter             F
# 17           10024          Milo             M
# 18           10024         Sasha             F
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?
#
# You'll want to do these separately, and filter for each.

# %%
merged_df.query("borough =='Bronx'").animal_name.value_counts()
# Out:
# Bella                  22
# Max                    21
# Rocky                  20
# Princess               15
# Lucky                  15
#                        ..
# Henny                   1
# MAXX                    1
# Ginger Gaston           1
# Frisco Melendez         1
# Montana Monti Nash      1
# Name: animal_name, Length: 2031, dtype: int64

# %%
merged_df.query("borough =='Brooklyn'").animal_name.value_counts()
# Out:
# Max            46
# unknown        45
# UNKNOWN        45
# Bella          45
# Charlie        42
#                ..
# GUINNESS        1
# Red Jupiter     1
# Becky           1
# Doug            1
# Zev             1
# Name: animal_name, Length: 4538, dtype: int64

# %%
merged_df.query("neighborhood =='Upper East Side'").animal_name.value_counts()
# Out:
# Charlie      19
# Bella        12
# NO NAME      11
# Lola         10
# Lucy         10
#              ..
# SEBASTAN      1
# Sigmund       1
# Macdougal     1
# Nikki         1
# OLIVE         1
# Name: animal_name, Length: 1382, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?
#
# * *Tip: There are a few ways to do this, and some are awful (see the "top 5 breeds in each borough" question below).*

# %%
#not sure how to show just the max value for each column#########################################
merged_df.groupby(by="neighborhood").primary_breed.value_counts().groupby(level=0).nlargest(1)
#df[df.guard_or_trained=="Yes"].primary_breed.value_counts()
# Out:
# neighborhood                   neighborhood                   primary_breed
# Borough Park                   Borough Park                   Yorkshire Terrier                        49
# Bronx Park and Fordham         Bronx Park and Fordham         Yorkshire Terrier                        39
# Bushwick and Williamsburg      Bushwick and Williamsburg      Yorkshire Terrier                        47
# Canarsie and Flatlands         Canarsie and Flatlands         Shih Tzu                                 56
# Central Bronx                  Central Bronx                  Yorkshire Terrier                        29
# Central Brooklyn               Central Brooklyn               Shih Tzu                                 52
# Central Harlem                 Central Harlem                 Chihuahua                                48
# Central Queens                 Central Queens                 Yorkshire Terrier                        34
# ...

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?
#
# * *Tip: This has a handful of interpretations, and some are easier than others. Feel free to skip it if you can't figure it out to your satisfaction.*

# %% [markdown]
# ## Make a new column called `monochrome` that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
#if the animal's dominant color is black, white, or grey and the other columns are Na, then add it to the monochrome column
df['monochrome'] = df.animal_dominant_color.isin(["Black", "White", "Grey"])

# %%
df
# Out:
#        owner_zip_code   animal_name animal_gender         primary_breed  \
# 0               10024     BLUE MACK             M                   NaN
# 1               10461  Indie Zephir             M            Rottweiler
# 2               10013         Bilal             M  Australian Cattledog
# 3               10025         Buddy             M                   NaN
# 4               10013           Ali             M               Basenji
# ...               ...           ...           ...                   ...
# 29995           11372         Bella             F                   NaN
# 29996           11417         Sadie             F  Schnauzer, Miniature
# 29997           11228       unknown             M            Pomeranian
# 29998           11217         daisy             F                   NaN
# 29999           10038       Squeeze             M              Shih Tzu
#
#       secondary_breed animal_dominant_color animal_secondary_color  \
# ...

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
merged_df.borough.value_counts().sort_values().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
df_population = pd.read_csv("boro_population.csv")
df_population
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
merged_df = merged_df.merge(df_population, left_on='borough', right_on='borough')
merged_df
# Out:
#        owner_zip_code animal_name animal_gender  \
# 0               10024   BLUE MACK             M
# 1               10024       Louie             M
# 2               10024       Tosha             F
# 3               10024     Poppett             F
# 4               10024      Harlen             M
# ...               ...         ...           ...
# 29568           11436        Jack             M
# 29569           11436  ROXY                   F
# 29570           11436       marco             M
# 29571           11436  Maximilian             M
# 29572           11005      Bichon             F
#
#                           primary_breed  secondary_breed  \
# 0                                   NaN    AIREDALE TERR
# 1                                   NaN        Coonhound
# 2                   Collie, Smooth Coat              NaN
# 3      Dachshund, Long Haired Miniature              NaN
# 4                                   NaN      Plott Hound
# ...

# %%
merged_df.borough.value_counts()
# Out:
# Manhattan        10478
# Brooklyn          7466
# Queens            6154
# Bronx             2748
# Staten Island     2727
# Name: borough, dtype: int64

# %%
#there's prob a shorter way....
manhattan_pc = 1644518/10478
brooklyn_pc = 2636735/7466
queens_pc = 2339150/6154
bronx_ps = 1455444/2748
staten_island_pc = 474558/2727

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.
